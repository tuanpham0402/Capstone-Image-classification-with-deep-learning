# %%
import os
import re

import tensorflow as tf
import tensorflow.python.platform
from tensorflow.python.platform import gfile
import numpy as np
import pandas as pd
import sklearn
from sklearn import cross_validation
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score, classification_report
from sklearn.svm import SVC, LinearSVC
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import time

print("QTUAN: Finish import libraries ")
# Out:
# QTUAN: Finish import libraries

# %%
#start_time = time.time()
model_dir = 'imagenet'
images_dir = 'images/'
list_images = [images_dir+f for f in os.listdir(images_dir) if re.search('jpg|JPG|jpeg|JPEG', f)]

print("QTUAN: Finish set environment ")
print(list_images)
#print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# QTUAN: Finish set environment
# ['images/algebra_0.jpeg', 'images/algebra_1.jpeg', 'images/algebra_10.jpeg', 'images/algebra_100.jpeg', 'images/algebra_101.jpeg', 'images/algebra_102.jpeg', 'images/algebra_103.jpeg', 'images/algebra_104.jpeg', 'images/algebra_105.jpeg', 'images/algebra_106.jpeg', 'images/algebra_107.jpeg', 'images/algebra_108.jpeg', 'images/algebra_109.jpeg', 'images/algebra_11.jpeg', 'images/algebra_110.jpeg', 'images/algebra_111.jpeg', 'images/algebra_112.jpeg', 'images/algebra_113.jpeg', 'images/algebra_114.jpeg', 'images/algebra_115.jpeg', 'images/algebra_116.jpeg', 'images/algebra_117.jpeg', 'images/algebra_118.jpeg', 'images/algebra_119.jpeg', 'images/algebra_12.jpeg', 'images/algebra_120.jpeg', 'images/algebra_121.jpeg', 'images/algebra_122.jpeg', 'images/algebra_123.jpeg', 'images/algebra_124.jpeg', 'images/algebra_125.jpeg', 'images/algebra_126.jpeg', 'images/algebra_127.jpeg', 'images/algebra_128.jpeg', 'images/algebra_129.jpeg', 'images/algebra_13.jpeg', 'images/algebra_130.jpeg', 'images/algebra_131.jpeg', 'images/algebra_132.jpeg', 'images/algebra_133.jpeg', 'images/algebra_134.jpeg', 'images/algebra_135.jpeg', 'images/algebra_136.jpeg', 'images/algebra_137.jpeg', 'images/algebra_138.jpeg', 'images/algebra_139.jpeg', 'images/algebra_14.jpeg', 'images/algebra_140.jpeg', 'images/algebra_141.jpeg', 'images/algebra_142.jpeg', 'images/algebra_143.jpeg', 'images/algebra_144.jpeg', 'images/algebra_145.jpeg', 'images/algebra_146.jpeg', 'images/algebra_147.jpeg', 'images/algebra_148.jpeg', 'images/algebra_149.jpeg', 'images/algebra_15.jpeg', 'images/algebra_150.jpeg', 'images/algebra_151.jpeg', 'images/algebra_152.jpeg', 'images/algebra_153.jpeg', 'images/algebra_154.jpeg', 'images/algebra_155.jpeg', 'images/algebra_156.jpeg', 'images/algebra_157.jpeg', 'images/algebra_158.jpeg', 'images/algebra_159.jpeg', 'images/algebra_16.jpeg', 'images/algebra_160.jpeg', 'images/algebra_161.jpeg', 'images/algebra_162.jpeg', 'images/algebra_163.jpeg', 'images/algebra_164.jpeg', 'images/algebra_165.jpeg', 'images/algebra_166.jpeg', 'images/algebra_167.jpeg', 'images/algebra_168.jpeg', 'images/algebra_169.jpeg', 'images/algebra_17.jpeg', 'images/algebra_170.jpeg', 'images/algebra_171.jpeg', 'images/algebra_172.jpeg', 'images/algebra_173.jpeg', 'images/algebra_174.jpeg', 'images/algebra_175.jpeg', 'images/algebra_176.jpeg', 'images/algebra_177.jpeg', 'images/algebra_178.jpeg', 'images/algebra_179.jpeg', 'images/algebra_18.jpeg', 'images/algebra_180.jpeg', 'images/algebra_181.jpeg', 'images/algebra_182.jpeg', 'images/algebra_183.jpeg', 'images/algebra_184.jpeg', 'images/algebra_185.jpeg', 'images/algebra_186.jpeg', 'images/algebra_187.jpeg', 'images/algebra_188.jpeg', 'images/algebra_189.jpeg', 'images/algebra_19.jpeg', 'images/algebra_190.jpeg', 'images/algebra_191.jpeg', 'images/algebra_192.jpeg', 'images/algebra_193.jpeg', 'images/algebra_194.jpeg', 'images/algebra_195.jpeg', 'images/algebra_196.jpeg', 'images/algebra_197.jpeg', 'images/algebra_198.jpeg', 'images/algebra_199.jpeg', 'images/algebra_2.jpeg', 'images/algebra_20.jpeg', 'images/algebra_200.jpeg', 'images/algebra_201.jpeg', 'images/algebra_202.jpeg', 'images/algebra_203.jpeg', 'images/algebra_204.jpeg', 'images/algebra_205.jpeg', 'images/algebra_206.jpeg', 'images/algebra_207.jpeg', 'images/algebra_208.jpeg', 'images/algebra_209.jpeg', 'images/algebra_21.jpeg', 'images/algebra_210.jpeg', 'images/algebra_211.jpeg', 'images/algebra_212.jpeg', 'images/algebra_213.jpeg', 'images/algebra_214.jpeg', 'images/algebra_215.jpeg', 'images/algebra_216.jpeg', 'images/algebra_217.jpeg', 'images/algebra_218.jpeg', 'images/algebra_219.jpeg', 'images/algebra_22.jpeg', 'images/algebra_220.jpeg', 'images/algebra_221.jpeg', 'images/algebra_222.jpeg', 'images/algebra_223.jpeg', 'images/algebra_224.jpeg', 'images/algebra_225.jpeg', 'images/algebra_226.jpeg', 'images/algebra_227.jpeg', 'images/algebra_228.jpeg', 'images/algebra_229.jpeg', 'images/algebra_23.jpeg', 'images/algebra_230.jpeg', 'images/algebra_231.jpe ...

# %%
def create_graph():
    with gfile.FastGFile(os.path.join(model_dir, 'classify_image_graph_def.pb'), 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        _ = tf.import_graph_def(graph_def, name='')

# %%
def extract_features(list_images):
    nb_features = 2048
    features = np.empty((len(list_images),nb_features))
    labels = []
    
    create_graph()
    
    with tf.Session() as sess:
        next_to_last_tensor = sess.graph.get_tensor_by_name('pool_3:0')
        
        for ind, image in enumerate(list_images):
            if (ind%100 == 0):
                print('Processing %s...' % (image))
            
            if not gfile.Exists(image):
                tf.logging.fatal('File does not exist %s', image)
            
            image_data = gfile.FastGFile(image, 'rb').read()
            predictions = sess.run(next_to_last_tensor,{'DecodeJpeg/contents:0': image_data})
            features[ind,:] = np.squeeze(predictions)
            labels.append(re.split('_\d+',image.split('/')[1])[0])

    return features, labels

# %%
# Extract feature
start_time = time.time()
features,labels = extract_features(list_images)
print("Label: ", labels)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Processing images/algebra_0.jpeg...
# Processing images/algebra_189.jpeg...
# Processing images/algebra_279.jpeg...
# Processing images/algebra_369.jpeg...
# Processing images/algebra_459.jpeg...
# Processing images/algebra_549.jpeg...
# Processing images/algebra_639.jpeg...
# Processing images/algebra_729.jpeg...
# Processing images/algebra_819.jpeg...
# Processing images/algebra_909.jpeg...
# Processing images/calculus_0.jpeg...
# Processing images/calculus_189.jpeg...
# Processing images/calculus_279.jpeg...
# Processing images/calculus_369.jpeg...
# Processing images/calculus_459.jpeg...
# Processing images/calculus_549.jpeg...
# Processing images/calculus_639.jpeg...
# Processing images/calculus_729.jpeg...
# Processing images/calculus_819.jpeg...
# Processing images/calculus_909.jpeg...
# Processing images/geometry_0.jpeg...
# Processing images/geometry_189.jpeg...
# Processing images/geometry_279.jpeg...
# Processing images/geometry_369.jpeg...
# Processing images/geometry_459.jpeg...
# Processing images/geometry_549.jpeg...
# Processing images/geometry_639.jpeg...
# Processing images/geometry_729.jpeg...
# Processing images/geometry_819.jpeg...
# Processing images/geometry_909.jpeg...
# Label:  ['algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra', 'algebra' ...
# --- 2517.4499447345734 seconds ---

# %%
# Save features and labels for reruning next times
pickle.dump(features, open('features', 'wb'))
pickle.dump(labels, open('labels', 'wb'))

# %%
# Load features and labels
features = pickle.load(open('features','rb'))
labels = pickle.load(open('labels','rb'))

# %%
# We will use 80% of the data as the training set and 20% as the test set
X_train, X_test, y_train, y_test = cross_validation.train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
# Classifying the images with a Linear Support Vector Machine (SVM)
start_time = time.time()
clf = LinearSVC(C=1.0, loss='squared_hinge', penalty='l2',multi_class='ovr')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 50.95807600021362 seconds ---

# %%
def plot_confusion_matrix(y_true,y_pred):
    cm_array = confusion_matrix(y_true,y_pred)
    true_labels = np.unique(y_true)
    pred_labels = np.unique(y_pred)
    plt.imshow(cm_array[:-1,:-1], interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix", fontsize=16)
    cbar = plt.colorbar(fraction=0.046, pad=0.04)
    cbar.set_label('Number of images', rotation=270, labelpad=30, fontsize=12)
    xtick_marks = np.arange(len(true_labels))
    ytick_marks = np.arange(len(pred_labels))
    plt.xticks(xtick_marks, true_labels, rotation=90)
    plt.yticks(ytick_marks,pred_labels)
    plt.tight_layout()
    plt.ylabel('True label', fontsize=14)
    plt.xlabel('Predicted label', fontsize=14)
    fig_size = plt.rcParams["figure.figsize"]
    fig_size[0] = 12
    fig_size[1] = 12
    plt.rcParams["figure.figsize"] = fig_size

# %%
print("Accuracy: {0:0.1f}%".format(accuracy_score(y_test,y_pred)*100))


print ('confusion matrix:')
print (confusion_matrix(y_test, y_pred))
# plot the confusion matrix
plt.imshow(confusion_matrix(y_test, y_pred), interpolation='nearest')
plt.show()
# Out:
# Accuracy: 37.0%
# confusion matrix:
# [[70 51 42 46]
#  [47 67 35 64]
#  [39 48 79 28]
#  [35 37 32 80]]
